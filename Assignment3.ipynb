# %% [markdown]
# # Assignment3

# %% [markdown]
# Today's assignment is to plot graph
# For
#
# 1. x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
# y=[99,86,87,88,111,86,103,87,94,78,77,85,86]

# %%
import matplotlib.pyplot as plt 
x= [5,7,8,7,2,17,2,9,4,11,12,9,6]
y=[99,86,87,88,111,86,103,87,94,78,77,85,86]
plt.scatter(x,y)
plt.plot(x, y) 
plt.xlabel('x - axis')  
plt.ylabel('y - axis')  
plt.title('Graph 1') 
plt.show()

# %% [markdown]
# 2. Log(x) for x= 1 to 10

# %%
x = [ i for i in range(1,11)]
y = np.log10(x) 
plt.scatter(x, y)
plt.xlabel("x")
plt.ylabel("y=log10(x)")
plt.title('Graph 2') 
plt.show()
